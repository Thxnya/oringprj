# %%
# gpu 확인
# !nvidia-smi
# Out:
# Thu Oct 27 02:18:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# 구글드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/intown/project/Source
# Out:
# /content/drive/MyDrive/intown/project/Source

# %%
# sinGAN 깃 클론
# !git clone https://github.com/dvschultz/SinGAN

# %%
# torch, torchvision 버전변경
# !pip install torch==1.4.0 torchvision==0.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 753.4 MB 6.6 kB/s
# ...
#      |████████████████████████████████| 4.0 MB 63.2 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.4.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.4.0 which is incompatible.
# ...

# %%
cd /content/drive/MyDrive/intown/project/Source/SinGAN
# Out:
# /content/drive/MyDrive/intown/project/Source/SinGAN

# %%
# 불량데이터 카테고리 입력
# ng_type = ['inner', 'outer', 'block', 'scar', 'tear']
ng_type = ['scar', 'tear']

# %%
# 정상데이터 학습
# !python main_train.py --input_name Max_Exposure_OK.jpg --max_size 128 --num_samples 1

# %%
# 불량데이터 학습
for i in ng_type:
  for j in range(2):
    # !python main_train.py --input_name {i}_{j}.jpg --max_size 128 --num_samples 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# scale 2:[1075/2000]
# scale 2:[1100/2000]
# scale 2:[1125/2000]
# scale 2:[1150/2000]
# scale 2:[1175/2000]
# scale 2:[1200/2000]
# scale 2:[1225/2000]
# scale 2:[1250/2000]
# scale 2:[1275/2000]
# scale 2:[1300/2000]
# scale 2:[1325/2000]
# scale 2:[1350/2000]
# scale 2:[1375/2000]
# scale 2:[1400/2000]
# scale 2:[1425/2000]
# scale 2:[1450/2000]
# scale 2:[1475/2000]
# scale 2:[1500/2000]
# scale 2:[1525/2000]
# scale 2:[1550/2000]
# scale 2:[1575/2000]
# scale 2:[1600/2000]
# scale 2:[1625/2000]
# scale 2:[1650/2000]
# scale 2:[1675/2000]
# scale 2:[1700/2000]
# scale 2:[1725/2000]
# scale 2:[1750/2000]
# scale 2:[1775/2000]
# scale 2:[1800/2000]
# scale 2:[1825/2000]
# scale 2:[1850/2000]
# scale 2:[1875/2000]
# scale 2:[1900/2000]
# scale 2:[1925/2000]
# scale 2:[1950/2000]
# scale 2:[1975/2000]
# scale 2:[1999/2000]
# GeneratorConcatSkip2CleanAdd(
#   (head): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
# ...

# %%
# !python random_samples.py --input_name Max_Exposure_OK.jpg --mode random_samples --gen_start_scale 1 --num_samples 27 --max_size 128
# Out:
# Random Seed:  6815

# %%
# 정상데이터 생성
for i in range(8):
  # !python random_samples.py --input_name Max_Exposure_OK.jpg --mode random_samples --gen_start_scale {i} --num_samples 47 --max_size 128
# Out:
# Random Seed:  2805
# random samples for image Max_Exposure_OK.jpg, start scale=0, already exist
# Random Seed:  3116
# random samples for image Max_Exposure_OK.jpg, start scale=1, already exist
# Random Seed:  4190
# random samples for image Max_Exposure_OK.jpg, start scale=2, already exist
# Random Seed:  2233
# random samples for image Max_Exposure_OK.jpg, start scale=3, already exist
# Random Seed:  2073
# random samples for image Max_Exposure_OK.jpg, start scale=4, already exist
# Random Seed:  3828
# random samples for image Max_Exposure_OK.jpg, start scale=5, already exist
# Random Seed:  4820
# random samples for image Max_Exposure_OK.jpg, start scale=6, already exist
# Random Seed:  5844
# random samples for image Max_Exposure_OK.jpg, start scale=7, already exist

# %%
# 불량데이터 생성
for i in ng_type:
  for j in range(2):
    for k in range(8):
      # !python random_samples.py --input_name {i}_{j}.jpg --mode random_samples --gen_start_scale {k} --num_samples 5 --max_size 128
# Out:
# Random Seed:  9536
# Random Seed:  1058
# Random Seed:  1182
# Random Seed:  1974
# Random Seed:  2684
# Random Seed:  6552
# Random Seed:  2302
# Random Seed:  1388
# Random Seed:  3146
# Random Seed:  2128
# Random Seed:  1610
# Random Seed:  7669
# Random Seed:  9772
# Random Seed:  4195
# Random Seed:  2967
# Random Seed:  7592
# Random Seed:  4290
# Random Seed:  9230
# Random Seed:  6990
# Random Seed:  3191
# Random Seed:  9660
# Random Seed:  7632
# Random Seed:  200
# Random Seed:  2089
# Random Seed:  8423
# Random Seed:  2363
# Random Seed:  7366
# Random Seed:  7795
# Random Seed:  9887
# Random Seed:  9722
# Random Seed:  1155
# Random Seed:  2185
