# %%
import pandas as pd

# %%
file_path = 'C:/Users/bcan6/Downloads/via_region_data.json'
df = pd.read_json(file_path)
df = df.T
df
# Out:
#                                                    fileref  size  \
# 0_png.rf.1b1de9505aec703d2ca0f0d25a00b44f.jpg2930           2930
# 0_png.rf.4a29847ac4448f802e713bbf3d2157b2.jpg2731           2731
# 0_png.rf.a94bafe70e944d3e9cf3086e0a6e421a.jpg3098           3098
# 1_png.rf.87346db14f84b89b76a8c9aa8786202b.jpg2923           2923
# 1_png.rf.f3b3de255fc5c3ed2738845d273f62a4.jpg3096           3096
# ...                                                    ...   ...
# tear--76-_png.rf.f311abf1dac553373cff4776efb3df...          2970
# tear--77-_png.rf.4e0f615a9f601e40f7c4d22b8ddb4d...          2972
# tear--77-_png.rf.ef72c78ebc97c0af6663c2bf5f8cc9...          3219
# tear--80-_png.rf.626b7c5082a1f6878f63c930f4fc4e...          2988
# tear--80-_png.rf.12621e40661b14bc863b6fe551fae3...          2776
#
#                                                                                              filename  \
# ...

# %%
for i in range(41):
    df.iloc[i]['regions']['0']['region_attributes'] = {'Class': 'ok'}
    print(df.iloc[i]['regions']['0']['region_attributes'])
# Out:
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}
# {'Class': 'ok'}

# %%
for i in range(41, len(df)):
    cls = df.iloc[i]['filename'][0:df.iloc[i]['filename'].find('-')]
    df.iloc[i]['regions']['0']['region_attributes'] = {'Class': f'{cls}'}

# %%
file_path = 'C:/Users/bcan6/Downloads/via_region_data.json'
df = df.T
df.to_json(file_path)
