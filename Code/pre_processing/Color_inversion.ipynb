# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/intown/project/Data/Oring_crop/Max_Exposure/NG/scar/0.jpg")
out = img.copy()
out = 255 - out
cv2_imshow(img)
cv2_imshow(out)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7EFFA950D0D0>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7EFFA947A410>
# -1
