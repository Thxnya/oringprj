# %%
import pandas as pd

# %%
file_path = 'C:/Users/bcan6/Downloads/balloon-20221104T064150Z-001/balloon/train/via_region_data.json'
df = pd.read_json(file_path)
df.drop(columns=['5013250607_26359229b6_b.jpg78220', '4955354786_337a598e4a_b.jpg214786', '3945575930_ce99a7e98d_b.jpg235167', '3342804367_f43682bb80_b.jpg241456', '2354829160_3f65a6bf6f_b.jpg185646', '155815494_800fc9aa32_b.jpg237106', '120853323_d4788431b9_b.jpg385195'], inplace=True)
df = df.T
df
# Out:
#                                     fileref     size  \
# 34020010494_e5cb88e1c4_k.jpg1115004          1115004
# 25899693952_7c8b8b9edc_k.jpg814535            814535
# 24362039530_b151b41a52_k.jpg708540            708540
# 18849792632_aad23ad513_k.jpg522255            522255
# 17178818589_16e58fc1e5_k.jpg1027862          1027862
# 17156759330_5af4f5a5b8_k.jpg1329220          1329220
# 16435593892_2aa8118f4a_k.jpg1515379          1515379
# 15717689633_5f7f78c28e_k.jpg1166902          1166902
# 15331928994_d5b82eb368_k.jpg760725            760725
# 15290896925_884ab33fd3_k.jpg1287786          1287786
# 14666848163_8be8e37562_k.jpg598628            598628
# 14321263043_b76ef054d3_k.jpg1307210          1307210
# 12288446656_2c6a90e6f5_k.jpg961794            961794
# 12288355124_5e340d3de3_k.jpg788806            788806
# 12288043903_fe1ea17a4e_k.jpg621744            621744
# 12037308314_e16fb3a0f7_k.jpg696051            696051
# 10464445726_6f1e3bbe6a_k.jpg712154            712154
# ...

# %%
df = df.T
df.to_json(file_path)
